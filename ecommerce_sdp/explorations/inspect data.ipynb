# %%
df = spark.sql("select * from ecommerce.silver.orders")
display(df)

# %%
df2 = spark.sql("select * from ecommerce.silver.customers")
display(df2 )

# %%
# %sql
drop table ecommerce.silver.customers
